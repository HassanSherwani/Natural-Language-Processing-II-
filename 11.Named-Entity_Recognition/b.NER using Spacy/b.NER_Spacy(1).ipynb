# %% [markdown]
# # Named Entity Recognition
# - using Spacy

# %% [markdown]
# # 1)- Importing key modules

# %%
#support both Python 2 and Python 3 with minimal overhead.
from __future__ import absolute_import, division, print_function

# I am an engineer. I care only about error not warning. So, let's be maverick and ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
# For data processing and maths

import pandas as pd
#For Visuals
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from matplotlib import rcParams
rcParams['figure.figsize'] = 11, 8
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %%
# For text we shall use Spacy

import spacy 
from spacy import displacy # for spacy visuals
nlp = spacy.load("en")

# %%
! pip install version_information

# %%
# first install: pip install version_information
# %reload_ext version_information
# %version_information pandas,spacy,seaborn, matplotlib
# Out:
# Software versions
# Python 3.6.8 64bit [GCC 8.3.0]
# IPython 5.5.0
# OS Linux 4.14.137+ x86_64 with Ubuntu 18.04 bionic
# pandas 0.25.3
# spacy 2.1.9
# seaborn 0.9.0
# matplotlib 3.1.1
# Sun Nov 24 20:27:41 2019 UTC

# %% [markdown]
# # 2)- Getting Data

# %%
text_select=nlp("""The Gabba remained unbreached as Australia wrapped up a win within four days, kickstarting their summer on a bright note." 
Pakistan, who made Australia work hard for that win on Sunday (November 24), were bowled out eventually for 355, conceding a win by an innings and 5 runs in Brisbane. 
This was Pakistan's fifth consecutive loss away from home, while Australia maintained their unbeaten record at the Gabba, not having lost a Test here since 1988.""")

# %%
type(text_select)
# Out:
# spacy.tokens.doc.Doc

# %%
text_select
# Out:
# The Gabba remained unbreached as Australia wrapped up a win within four days, kickstarting their summer on a bright note."
# Pakistan, who made Australia work hard for that win on Sunday (November 24), were bowled out eventually for 355, conceding a win by an innings and 5 runs in Brisbane.
# This was Pakistan's fifth consecutive loss away from home, while Australia maintained their unbeaten record at the Gabba, not having lost a Test here since 1988.

# %%
print([x for x in text_select])
# Out:
# [The, Gabba, remained, unbreached, as, Australia, wrapped, up, a, win, within, four, days, ,, kickstarting, their, summer, on, a, bright, note, ., ",
# , Pakistan, ,, who, made, Australia, work, hard, for, that, win, on, Sunday, (, November, 24, ), ,, were, bowled, out, eventually, for, 355, ,, conceding, a, win, by, an, innings, and, 5, runs, in, Brisbane, .,
# , This, was, Pakistan, 's, fifth, consecutive, loss, away, from, home, ,, while, Australia, maintained, their, unbeaten, record, at, the, Gabba, ,, not, having, lost, a, Test, here, since, 1988, .]

# %%
for entity in text_select.ents:
    print(entity.text)
# Out:
# Gabba
# Australia
# four days
# summer
# Pakistan
# Australia
# Sunday (November 24
# 355
# 5
# Brisbane
# Pakistan
# fifth
# Australia
# Gabba
# Test
# 1988

# %%
for entity in text_select.ents:
    print(entity.text, entity.label_)
# Out:
# Gabba PERSON
# Australia GPE
# four days DATE
# summer DATE
# Pakistan GPE
# Australia GPE
# Sunday (November 24 DATE
# 355 CARDINAL
# 5 CARDINAL
# Brisbane GPE
# Pakistan GPE
# fifth ORDINAL
# Australia GPE
# Gabba LOC
# Test NORP
# 1988 DATE

# %%
for entity in text_select.ents:
    print(entity.text, entity.label_)
# Out:
# Gabba PERSON
# Australia GPE
# four days DATE
# summer DATE
# Pakistan GPE
# Australia GPE
# Sunday (November 24 DATE
# 355 CARDINAL
# 5 CARDINAL
# Brisbane GPE
# Pakistan GPE
# fifth ORDINAL
# Australia GPE
# Gabba LOC
# Test NORP
# 1988 DATE

# %% [markdown]
# We can see that Gabba is identified as "Person" and "LOC". It is actually in GPE in both cases. So, it is good method from spacy but, not perfect.

# %%
spacy.explain('LOC')
# Out:
# 'Non-GPE locations, mountain ranges, bodies of water'

# %%
spacy.explain('GPE')
# Out:
# 'Countries, cities, states'

# %%
spacy.explain('NORP')
# Out:
# 'Nationalities or religious or political groups'

# %%
spacy.explain('CARDINAL')
# Out:
# 'Numerals that do not fall under another type'

# %% [markdown]
# ### visualization with SPacy

# %%
displacy.render(text_select,style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Gabba
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  remained unbreached as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  wrapped up a win within
# ...

# %%
from spacy import displacy

displacy.render(text_select, style= 'dep', jupyter= True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4c2009c4944e4632999da74a6a939610-0" class="displacy" width="13875" height="1099.5" direction="ltr" style="max-width: none; height: 1099.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Gabba</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">remained</tspan>
# ...
